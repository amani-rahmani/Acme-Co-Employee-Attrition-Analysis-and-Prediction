# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Exporation
#
# This involves getting familiar with your data. You want to understand:
#
#     Structure: How many rows and columns does the data have? What are the data types of each column (numerical, text, etc.)?
#     Content: What do the column names represent? Are there any summary statistics you can calculate (mean, median, etc.)?

# %%
import pandas as pd

#info about the dataset
dataset = pd.read_csv('/content/Employee-Attrition.csv')
# number of rows and columns in the dataframe
dataset.shape
# Out:
# (1470, 35)

# %%
#info about the dataset
dataset.info()

# %%
#checking if theres any missing values
dataset.isnull().sum()

# %%
#stastical info about the data
dataset.describe()

# %% [markdown]
# # Data Cleaning
# *      Missing Values: Decide how to handle missing values (e.g., remove rows,impute with mean/median).
#
# *       Outliers: Identify and address extreme values that might skew analysis.
#
#
# *
#     Inconsistent Formatting: Ensure consistent formatting throughout the data (e.g., convert dates to a standard format).

# %%
# Droping rows with missing values
dataset.dropna(inplace=True)

# %% [markdown]
# # descriptive data analysis

# %% [markdown]
# **bold text**# 1 identifying most important factors in employee attrition

# %%
#info about the dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#if lifestyle is a factor in attrition
dataset.BusinessTravel
dataset.WorkLifeBalance
dataset.DistanceFromHome
#employee demographics  if  marriage is a factor in attrition if age is a factor in attrition what demographics leavs the most men women older
dataset.RelationshipSatisfaction
dataset.MaritalStatus
dataset.JobSatisfaction
#if the job role and level is a factor
dataset.JobLevel
dataset.JobRole

# %%
#if the company environment is a factor
dataset.EnvironmentSatisfaction

# %%
#if money is a factor in atrrition
dataset.HourlyRate
dataset.StandardHours
dataset.OverTime
dataset.MonthlyIncome
dataset.OverTime

# %% [markdown]
# # The analysis

# %%
# Change Factors to Numerics
dataset['Attrition'] = Dateset['Attrition'].apply (lambda x: 1 if x == "Yes" else 0)
dataset['OverTime'] = dataset['OverTime'].apply (lambda x: 1 if x == "Yes" else 0)

# %%
attrition_count = pd.DataFrame(dataset['Attrition'].value_counts())

sns.countplot(dataset['Attrition'])

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No','Yes'] , explode = (0.2,0))
plt.show()

# %%
dataset.drop(['EmployeeCount' , 'EmployeeNumber'] , axis = 1)

# %%
attrition_dummies = pd.get_dummies(dataset['Attrition'])
attrition_dummies.head()

# %%
dataset = pd.concat([dataset, attrition_dummies] , axis = 1)
dataset.head()

# %%
dataset = dataset.drop(['Attrition' , 'No'] , axis = 1)
dataset.head()

# %%
sns.barplot(x = 'Gender' , y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'Department', y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'BusinessTravel', y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'JobLevel', y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'OverTime', y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'Age', y = 'Yes', data = dataset)

# %%
sns.barplot(x = 'EnvironmentSatisfaction', y = 'Yes', data = dataset)
